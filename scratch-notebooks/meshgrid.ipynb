# %%
import numpy as np

x_vals = np.linspace(0, 1, 50)
y_vals = np.linspace(2, 3, 25)

xx, yy = np.meshgrid(x_vals, y_vals)

print(xx.shape)
print(xx)
# Out:
# (25, 50)
# [[0.         0.02040816 0.04081633 ... 0.95918367 0.97959184 1.        ]
#  [0.         0.02040816 0.04081633 ... 0.95918367 0.97959184 1.        ]
#  [0.         0.02040816 0.04081633 ... 0.95918367 0.97959184 1.        ]
#  ...
#  [0.         0.02040816 0.04081633 ... 0.95918367 0.97959184 1.        ]
#  [0.         0.02040816 0.04081633 ... 0.95918367 0.97959184 1.        ]
#  [0.         0.02040816 0.04081633 ... 0.95918367 0.97959184 1.        ]]
